# %%
# %pylab inline
import matplotlib.pyplot as pl
import seaborn as sns
import numpy as np
sns.set_palette('husl')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def pairs(data):
    """Generates and shows a pairwise scatterplot of the dataset features.

    A figure with nxn scatterplots is generated, where n is the number of features. The features are
    defined as the all columns excluding the final column, which is defined as the class.

    Args:
      data (array): A dataset.

    """
    i = 1

    # Divide columns into features and class.
    features = list(data.columns)
    classes = features[-1] # create class column
    del features[-1] # delete class column from feature vector

    # Generate an nxn subplot figure, where n is the number of features.
    figure = pl.figure(figsize=(5*(len(data.columns)-1), 4*(len(data.columns)-1)))
    for col1 in data[features]:
        for col2 in data[features]:
            ax = pl.subplot(len(data.columns)-1, len(data.columns)-1, i)
            if col1 == col2:
                ax.text(2.5, 4.5, col1, style='normal', fontsize=20)
                ax.axis([0, 10, 0, 10])
                pl.xticks([]), pl.yticks([])
            else:
                for name in data[classes]:
                    cond = data[classes] == name
                    ax.plot(data[col2][cond], data[col1][cond], linestyle='none', marker='o', label=name)
                #t = plt.title(name)
            i += 1

    pl.show()

# %%
import pandas as pd

fileURL = 'http://archive.ics.uci.edu/ml/\
machine-learning-databases/iris/iris.data'
iris = pd.read_csv(fileURL, names=['Sepal Length', 'Sepal Width', \
                                   'Petal Length', 'Petal Width', 
                                   'Species'], header=None)
iris = iris.dropna()

# %% [markdown]
# ***
# Using the given pairs function to plot a scatterplot for pairwise combination.

# %%
iris.head()
pairs(iris)

# %% [markdown]
# ***
# Plot of the linear regression models for pairwise combination of features, and corresponding model statistics.

# %%
import sklearn.cross_validation
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

x = iris[['Sepal Length']]
y = iris[['Sepal Width']]

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

lm = LinearRegression()

lm.fit(X_train, y_train)

predictions = lm.predict(X_test)

    # The coefficient(s).
print("Coefficient:", lm.coef_)

    # The mean square error.
print ("Mean squared error: %.2f" % np.mean(((predictions - y_test) ** 2)))

    # Explained variance score (1 is perfect prediction).
print ("Variance score: %.2f" % lm.score(X_test, y_test))

pl.scatter(X_test, y_test, color = 'red')
pl.plot(X_test, predictions, color = 'blue')
pl.xlabel('Sepal Length')
pl.ylabel('Sepal Width')

pl.show()
# Out:
# /Users/suhaniladani/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# Coefficient: [[-0.01655308]]
# Mean squared error: 0.20
# Variance score: -0.01

# %%
import sklearn.cross_validation
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

x = iris[['Sepal Length']]
y = iris[['Petal Length']]

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

lm = LinearRegression()

lm.fit(X_train, y_train)

predictions = lm.predict(X_test)

    # The coefficient(s).
print("Coefficient:", lm.coef_)

    # The mean square error.
print ("Mean squared error: %.2f" % np.mean(((predictions - y_test) ** 2)))

    # Explained variance score (1 is perfect prediction).
print ("Variance score: %.2f" % lm.score(X_test, y_test))

pl.scatter(X_test, y_test, color = 'red')
pl.plot(X_test, predictions, color = 'blue')
pl.xlabel('Sepal Length')
pl.ylabel('Petal Length')

pl.show()
# Out:
# Coefficient: [[1.84466559]]
# Mean squared error: 0.94
# Variance score: 0.71

# %%
import sklearn.cross_validation
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

x = iris[['Sepal Length']]
y = iris[['Petal Width']]

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

lm = LinearRegression()

lm.fit(X_train, y_train)

predictions = lm.predict(X_test)

    # The coefficient(s).
print("Coefficient:", lm.coef_)

    # The mean square error.
print ("Mean squared error: %.2f" % np.mean(((predictions - y_test) ** 2)))

    # Explained variance score (1 is perfect prediction).
print ("Variance score: %.2f" % lm.score(X_test, y_test))

pl.scatter(X_test, y_test, color = 'red')
pl.plot(X_test, predictions, color = 'blue')
pl.xlabel('Sepal Length')
pl.ylabel('Petal Width')

pl.show()
# Out:
# Coefficient: [[0.76761533]]
# Mean squared error: 0.22
# Variance score: 0.62

# %%
import sklearn.cross_validation
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

x = iris[['Sepal Width']]
y = iris[['Petal Length']]

# split into test and train
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

lm = LinearRegression()

# fit the model
lm.fit(X_train, y_train)

predictions = lm.predict(X_test)

    # The coefficient(s).
print("Coefficient:", lm.coef_)

    # The mean square error.
print ("Mean squared error: %.2f" % np.mean(((predictions - y_test) ** 2)))

    # Explained variance score (1 is perfect prediction).
print ("Variance score: %.2f" % lm.score(X_test, y_test))

pl.scatter(X_test, y_test, color = 'red')
pl.plot(X_test, predictions, color = 'blue')
pl.xlabel('Sepal Width')
pl.ylabel('Petal Length')

pl.show()
# Out:
# Coefficient: [[-1.69797181]]
# Mean squared error: 2.24
# Variance score: 0.23

# %%
import sklearn.cross_validation
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

x = iris[['Sepal Width']]
y = iris[['Petal Width']]

# split into test and train
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

lm = LinearRegression()

#fit the model
lm.fit(X_train, y_train)

predictions = lm.predict(X_test)

    # The coefficient(s).
print("Coefficient:", lm.coef_)

    # The mean square error.
print ("Mean squared error: %.2f" % np.mean(((predictions - y_test) ** 2)))

    # Explained variance score (1 is perfect prediction).
print ("Variance score: %.2f" % lm.score(X_test, y_test))

pl.scatter(X_test, y_test, color = 'red')
pl.plot(X_test, predictions, color = 'blue')
pl.xlabel('Sepal Width')
pl.ylabel('Petal Width')

pl.show()
# Out:
# Coefficient: [[-0.62211898]]
# Mean squared error: 0.55
# Variance score: 0.15

# %%
x = iris[['Petal Length']]
y = iris[['Petal Width']]

# split into test and train
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

lm = LinearRegression()

# Fit the linear model
lm.fit(X_train, y_train)

predictions = lm.predict(X_test)

# The coefficient(s).
print("Coefficient:", lm.coef_)

# The mean square error.
print ("Mean squared error: %.2f" % np.mean(((predictions - y_test) ** 2)))

# Explained variance score (1 is perfect prediction).
print ("Variance score: %.2f" % lm.score(X_test, y_test))

pl.scatter(X_test, y_test, color = 'red')
pl.plot(X_test, predictions, color = 'blue')
pl.xlabel('Petal Length')
pl.ylabel('Petal Width')

pl.show()
# Out:
# Coefficient: [[0.39797004]]
# Mean squared error: 0.07
# Variance score: 0.91

# %% [markdown]
# ***
# Using the multiple feature combination to plot the regression model.

# %%
X = iris[['Petal Length', 'Sepal Length']]
y = iris[['Petal Width']]

sns.pairplot(iris, x_vars=['Petal Length', 'Sepal Length'], y_vars=['Petal Width'], size=5, aspect=.8, kind="reg");

# Fit the linear model
model = LinearRegression()
results = model.fit(X, y)
# The coefficient(s).

# %%
X = iris[['Petal Length', 'Sepal Length']]
y = iris[['Sepal Width']]

sns.pairplot(iris, x_vars=['Petal Length', 'Sepal Length'], y_vars=['Sepal Width'], size=5, aspect=.8, kind="reg");

# Fit the linear model
model = LinearRegression()
results = model.fit(X, y)

# %%
X = iris[['Petal Length', 'Petal Width']]
y = iris[['Sepal Length']]

sns.pairplot(iris, x_vars=['Petal Length', 'Petal Width'], y_vars=['Sepal Length'], size=5, aspect=.8, kind="reg");

# Fit the linear model
model = LinearRegression()
results = model.fit(X, y)

# %%
X = iris[['Petal Length', 'Petal Width']]
y = iris[['Sepal Width']]

sns.pairplot(iris, x_vars=['Petal Length', 'Petal Width'], y_vars=['Sepal Width'], size=5, aspect=.8, kind="reg");

# Fit the linear model
model = LinearRegression()
results = model.fit(X, y)

# %%
X = iris[['Petal Width', 'Sepal Width']]
y = iris[['Petal Length']]

sns.pairplot(iris, x_vars=['Petal Width', 'Sepal Width'], y_vars=['Petal Length'], size=5, aspect=.8, kind="reg");

# Fit the linear model
model = LinearRegression()
results = model.fit(X, y)

# %%
X = iris[['Petal Width', 'Sepal Width']]
y = iris[['Sepal Length']]

sns.pairplot(iris, x_vars=['Petal Width', 'Sepal Width'], y_vars=['Sepal Length'], size=5, aspect=.8, kind="reg");

# Fit the linear model
model = LinearRegression()
results = model.fit(X, y)

# %% [markdown]
# ***
# The plot of the best of the set of linear regression models generated in the last step; and the corresponding model statistics.

# %%
x = iris[['Petal Length']]
y = iris[['Petal Width']]

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

lm = LinearRegression()

lm.fit(X_train, y_train)

predictions = lm.predict(X_test)

# The coefficient(s).
print("Coefficient:", lm.coef_)

    # The mean square error.
print ("Mean squared error: %.2f" % np.mean(((predictions - y_test) ** 2)))

    # Explained variance score (1 is perfect prediction).
print ("Variance score: %.2f" % lm.score(X_test, y_test))

pl.scatter(X_test, y_test, color = 'red')
pl.plot(X_test, predictions, color = 'blue')
pl.xlabel('Petal Length')
pl.ylabel('Petal Width')

pl.show()
# Out:
# Coefficient: [[0.42064883]]
# Mean squared error: 0.04
# Variance score: 0.93

# %% [markdown]
# ***
# Given the output, answers to given questions:
#
# ##### Answer 1
# The pair of features that appear to be most predictive for one another are petal length and petal width. The result is based on the linear models generated.
#
# ##### Answer 2
# Removing the petal width feature (the best predicted feature) would not have a significant effect on classification performance. This is because the majority of the information that can be obtained from petal width can also be obtained from some formula involving the other three features.
#
# The prediction of the petal width from the other features (petal length, sepal width, sepal length) is also a measure of its prolixity with respect to these features. Thus it would not have a major effect on classification model.

# %% [markdown]
# ##### References
# 1. https://seaborn.pydata.org/generated/seaborn.pairplot.html
# 2. http://scikit-learn.org/stable/auto_examples/linear_model/plot_ols.html
# 3. http://nbviewer.jupyter.org/github/cse40647/cse40647/blob/sp.14/assignment3/assignment3_sol.ipynb
# 4. http://scikit-learn.org/stable/modules/generated/sklearn.metrics.mean_squared_error.html
